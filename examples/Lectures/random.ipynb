# %%
import random

# %%
from dice_6M_return import dice

# %%
result = dice(60)
print(result)
# Out:
# Face    Frequency
#    1       999213
#    2      1002035
#    3      1001271
#    4       999563
#    5       998942
#    6       998976
# [999213, 1002035, 1001271, 999563, 998942, 998976]

# %%
import matplotlib.pyplot as plt
xco = [1, 2, 3, 4, 5, 6]
plt.bar(xco,result, align='center', alpha=0.5)
# Out:
# <BarContainer object of 6 artists>
